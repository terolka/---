# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка данных</a></span></li><li><span><a href="#Проведите-исследовательский-анализ-данных-(EDA)" data-toc-modified-id="Проведите-исследовательский-анализ-данных-(EDA)-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Проведите исследовательский анализ данных (EDA)</a></span><ul class="toc-item"><li><span><a href="#Посмотрите-на-датасет:-есть-ли-в-нем-отсутствующие-признаки,-изучите-средние-значения-и-стандартные-отклонения-(пригодится-метод-describe())" data-toc-modified-id="Посмотрите-на-датасет:-есть-ли-в-нем-отсутствующие-признаки,-изучите-средние-значения-и-стандартные-отклонения-(пригодится-метод-describe())-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Посмотрите на датасет: есть ли в нем отсутствующие признаки, изучите средние значения и стандартные отклонения (пригодится метод describe())</a></span></li><li><span><a href="#Посмотрите-на-средние-значения-признаков-в-двух-группах-—-тех,-кто-ушел-в-отток-и-тех,-кто-остался-(воспользуйтесь-методом-groupby())" data-toc-modified-id="Посмотрите-на-средние-значения-признаков-в-двух-группах-—-тех,-кто-ушел-в-отток-и-тех,-кто-остался-(воспользуйтесь-методом-groupby())-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Посмотрите на средние значения признаков в двух группах — тех, кто ушел в отток и тех, кто остался (воспользуйтесь методом groupby())</a></span></li><li><span><a href="#Постройте-столбчатые-гистограммы-и-распределения-признаков-для-тех,-кто-ушёл-(отток)-и-тех,-кто-остался-(не-попали-в-отток)" data-toc-modified-id="Постройте-столбчатые-гистограммы-и-распределения-признаков-для-тех,-кто-ушёл-(отток)-и-тех,-кто-остался-(не-попали-в-отток)-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Постройте столбчатые гистограммы и распределения признаков для тех, кто ушёл (отток) и тех, кто остался (не попали в отток)</a></span></li><li><span><a href="#Постройте-матрицу-корреляций-и-отобразите-её" data-toc-modified-id="Постройте-матрицу-корреляций-и-отобразите-её-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Постройте матрицу корреляций и отобразите её</a></span></li></ul></li><li><span><a href="#Постройте-модель-прогнозирования-оттока-клиентов" data-toc-modified-id="Постройте-модель-прогнозирования-оттока-клиентов-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Постройте модель прогнозирования оттока клиентов</a></span><ul class="toc-item"><li><span><a href="#Разбейте-данные-на-обучающую-и-валидационную-выборку-функцией-train_test_split()" data-toc-modified-id="Разбейте-данные-на-обучающую-и-валидационную-выборку-функцией-train_test_split()-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Разбейте данные на обучающую и валидационную выборку функцией train_test_split()</a></span></li><li><span><a href="#Обучите-модель-на-train-выборке-двумя-способами:-логистической-регрессией-и-случайным-лесом.-Оцените-метрики-accuracy,-precision-и-recall-для-обеих-моделей-на-валидационной-выборке.-Сравните-по-ним-модели.-Какая-модель-показала-себя-лучше-на-основании-метрик?" data-toc-modified-id="Обучите-модель-на-train-выборке-двумя-способами:-логистической-регрессией-и-случайным-лесом.-Оцените-метрики-accuracy,-precision-и-recall-для-обеих-моделей-на-валидационной-выборке.-Сравните-по-ним-модели.-Какая-модель-показала-себя-лучше-на-основании-метрик?-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Обучите модель на train-выборке двумя способами: логистической регрессией и случайным лесом. Оцените метрики accuracy, precision и recall для обеих моделей на валидационной выборке. Сравните по ним модели. Какая модель показала себя лучше на основании метрик?</a></span></li></ul></li><li><span><a href="#Сделайте-кластеризацию-клиентов" data-toc-modified-id="Сделайте-кластеризацию-клиентов-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Сделайте кластеризацию клиентов</a></span><ul class="toc-item"><li><span><a href="#Стандартизируйте-данные" data-toc-modified-id="Стандартизируйте-данные-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Стандартизируйте данные</a></span></li><li><span><a href="#Постройте-матрицу-расстояний-функцией-linkage()-на-стандартизованной-матрице-признаков-и-нарисуйте-дендрограмму.--На-основании-полученного-графика-предположите,-какое-количество-кластеров-можно-выделить." data-toc-modified-id="Постройте-матрицу-расстояний-функцией-linkage()-на-стандартизованной-матрице-признаков-и-нарисуйте-дендрограмму.--На-основании-полученного-графика-предположите,-какое-количество-кластеров-можно-выделить.-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Постройте матрицу расстояний функцией linkage() на стандартизованной матрице признаков и нарисуйте дендрограмму.  На основании полученного графика предположите, какое количество кластеров можно выделить.</a></span></li><li><span><a href="#Обучите-модель-кластеризации-на-основании-алгоритма-K-Means-и-спрогнозируйте-кластеры-клиентов.-Договоримся-за-число-кластеров-принять-n=5" data-toc-modified-id="Обучите-модель-кластеризации-на-основании-алгоритма-K-Means-и-спрогнозируйте-кластеры-клиентов.-Договоримся-за-число-кластеров-принять-n=5-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Обучите модель кластеризации на основании алгоритма K-Means и спрогнозируйте кластеры клиентов. Договоримся за число кластеров принять n=5</a></span></li><li><span><a href="#Посмотрите-на-средние-значения-признаков-для-кластеров.-Можно-ли-сразу-что-то-заметить?" data-toc-modified-id="Посмотрите-на-средние-значения-признаков-для-кластеров.-Можно-ли-сразу-что-то-заметить?-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Посмотрите на средние значения признаков для кластеров. Можно ли сразу что-то заметить?</a></span></li><li><span><a href="#Постройте-распределения-признаков-для-кластеров.-Можно-ли-что-то-заметить-по-ним?" data-toc-modified-id="Постройте-распределения-признаков-для-кластеров.-Можно-ли-что-то-заметить-по-ним?-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Постройте распределения признаков для кластеров. Можно ли что-то заметить по ним?</a></span></li><li><span><a href="#Для-каждого-полученного-кластера-посчитайте-долю-оттока-(методом-groupby()).-Отличаются-ли-они-по-доле-оттока?-Какие-кластеры-склонны-к-оттоку,-а-какие-—-надёжны?" data-toc-modified-id="Для-каждого-полученного-кластера-посчитайте-долю-оттока-(методом-groupby()).-Отличаются-ли-они-по-доле-оттока?-Какие-кластеры-склонны-к-оттоку,-а-какие-—-надёжны?-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Для каждого полученного кластера посчитайте долю оттока (методом groupby()). Отличаются ли они по доле оттока? Какие кластеры склонны к оттоку, а какие — надёжны?</a></span></li></ul></li><li><span><a href="#Сформулируйте-выводы-и-сделайте-базовые-рекомендации-по-работе-с-клиентами" data-toc-modified-id="Сформулируйте-выводы-и-сделайте-базовые-рекомендации-по-работе-с-клиентами-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Сформулируйте выводы и сделайте базовые рекомендации по работе с клиентами</a></span></li></ul></div>

# %% [markdown]
# **Описание проекта**

# %% [markdown]
# Сеть фитнес-центров «Культурист-датасаентист» разрабатывает стратегию взаимодействия с клиентами на основе аналитических данных. Распространённая проблема фитнес-клубов и других сервисов — отток клиентов. Как понять, что клиент больше не с вами? Можно записать в отток тех, кто попросил закрыть договор или удалил аккаунт. Однако клиенты не всегда уходят демонстративно: чаще перестают пользоваться сервисом тихо. Индикаторы оттока зависят от специфики отрасли. Когда пользователь редко, но стабильно закупается в интернет-магазине — не похоже, что он «отвалился». А вот если две недели не заходит на канал с ежедневно обновляемым контентом, дела плохи: подписчик заскучал и, кажется, оставил вас. Для фитнес-центра можно считать, что клиент попал в отток, если за последний месяц ни разу не посетил спортзал. Конечно, не исключено, что он уехал на Бали и по приезде обязательно продолжит ходить на фитнес. Однако чаще бывает наоборот. Если клиент начал новую жизнь с понедельника, немного походил в спортзал, а потом пропал — скорее всего, он не вернётся. Чтобы бороться с оттоком, отдел по работе с клиентами «Культуриста-датасаентиста» перевёл в электронный вид множество клиентских анкет.

# %% [markdown]
# ## Загрузка данных

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#from matplotlib import pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
from sklearn.ensemble import RandomForestClassifier
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import KMeans

# %%
df = pd.read_csv('/datasets/gym_churn.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             4000 non-null   int64
#  1   Near_Location                      4000 non-null   int64
#  2   Partner                            4000 non-null   int64
#  3   Promo_friends                      4000 non-null   int64
#  4   Phone                              4000 non-null   int64
#  5   Contract_period                    4000 non-null   int64
#  6   Group_visits                       4000 non-null   int64
#  7   Age                                4000 non-null   int64
#  8   Avg_additional_charges_total       4000 non-null   float64
#  9   Month_to_end_contract              4000 non-null   float64
#  10  Lifetime                           4000 non-null   int64
# ...

# %% [markdown]
# Всего в таблице 14 столбцов и 4000 колонок. Все типы данных корректные. Названия столбцов приведем к нижнему регистру.

# %%
df['Month_to_end_contract'] = df['Month_to_end_contract'].astype('int')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             4000 non-null   int64
#  1   Near_Location                      4000 non-null   int64
#  2   Partner                            4000 non-null   int64
#  3   Promo_friends                      4000 non-null   int64
#  4   Phone                              4000 non-null   int64
#  5   Contract_period                    4000 non-null   int64
#  6   Group_visits                       4000 non-null   int64
#  7   Age                                4000 non-null   int64
#  8   Avg_additional_charges_total       4000 non-null   float64
#  9   Month_to_end_contract              4000 non-null   int64
#  10  Lifetime                           4000 non-null   int64
# ...

# %%
df.columns = df.columns.str.lower()

# %% [markdown]
# ## Проведите исследовательский анализ данных (EDA)

# %% [markdown]
# ### Посмотрите на датасет: есть ли в нем отсутствующие признаки, изучите средние значения и стандартные отклонения (пригодится метод describe())

# %%
df.isna().sum()
# Out:
# gender                               0
# near_location                        0
# partner                              0
# promo_friends                        0
# phone                                0
# contract_period                      0
# group_visits                         0
# age                                  0
# avg_additional_charges_total         0
# month_to_end_contract                0
# lifetime                             0
# avg_class_frequency_total            0
# avg_class_frequency_current_month    0
# churn                                0
# dtype: int64

# %% [markdown]
# Пропущенных значений нет. Проверим дубликаты.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Дубликатов тоже нет

# %%
df.head()
# Out:
#    gender  near_location  partner  promo_friends  phone  contract_period  \
# 0       1              1        1              1      0                6
# 1       0              1        0              0      1               12
# 2       0              1        1              0      1                1
# 3       0              1        1              1      1               12
# 4       1              1        1              1      1                1
#
#    group_visits  age  avg_additional_charges_total  month_to_end_contract  \
# 0             1   29                     14.227470                      5
# 1             1   31                    113.202938                     12
# 2             0   28                    129.448479                      1
# 3             1   33                     62.669863                     12
# 4             0   26                    198.362265                      1
#
#    lifetime  avg_class_frequency_total  avg_class_frequency_current_month  \
# ...

# %%
df.describe()
# Out:
#             gender  near_location      partner  promo_friends        phone  \
# count  4000.000000    4000.000000  4000.000000    4000.000000  4000.000000
# mean      0.510250       0.845250     0.486750       0.308500     0.903500
# std       0.499957       0.361711     0.499887       0.461932     0.295313
# min       0.000000       0.000000     0.000000       0.000000     0.000000
# 25%       0.000000       1.000000     0.000000       0.000000     1.000000
# 50%       1.000000       1.000000     0.000000       0.000000     1.000000
# 75%       1.000000       1.000000     1.000000       1.000000     1.000000
# max       1.000000       1.000000     1.000000       1.000000     1.000000
#
#        contract_period  group_visits          age  \
# count      4000.000000   4000.000000  4000.000000
# mean          4.681250      0.412250    29.184250
# std           4.549706      0.492301     3.258367
# min           1.000000      0.000000    18.000000
# ...

# %% [markdown]
#  - По столбцу 'gender' распределение практически равное, cтандартное отклонение - 0.5;
#  - Из столбца 'near_location' видно, что примерно 80% клиентов проживают или работают в районе фитнес-центра, стандартное отклонение  - 0.36;
#  - Столбец 'partner' показывает, что почти половина клиентов - сотрудники компании-партнёра клуба, стандартное отклонение - 0.5;
#  - Столбец 'promo_friends' показывает, что 30% клиентов использовали промо-код при оплате первого абонемента, стандартное отклонение - 0.46;
#  - 90% клиентов указали контактный телефон (cтолбец 'phone'),cтандартное отклонение - 0.29;
#  - Из столбца 'contract_period' видно, что средняя длительность абонемента 4-5 месяцев, максимальное значение - 12 месяцев, стандартное отклонение - 4,5. Скорее всего, присутствуют выбросы;
#  - Столбец 'group_visits' показывает, что 41% клиентов посещают групповые занятия, стандартное отклонение - 0.49;
#  - Cреднее значение возраста клиентов(столбец 'age') - 29 лет, стандартное отклонение - 3,25. Минимальный возраст - 18 лет, максимальный - 41;
#  - Средняя выручка от других услуг фитнес-центра (столбец 'avg_additional_charges_total')   -  147 у.е., стандартное отклонение  - 96.4;
#  - Столбец 'month_to_end_contract' показывает, что cредний срок до окончания текущего действующего абонемента - 4 месяца, стандартное отклонение - 4,19. Клиентов, у которых заканчивается абонемент больше, чем клиентов, у которых абонемент только начался;
#  - Столбец 'lifetime' показывает, что средеяя продолжительность посещения фитнес-центра  3 месяца, стандартное отклонение - 3.7,  максимальная продолжительность посещения - 31 месяц;
#  - Средняя частота посещений в неделю (Столбец 'avg_class_frequency_total') - 1-2 раза, cтандартное отклонение - 0.9, максимальная частота - 6 дней в неделю;
#  - Cредняя частота посещений в неделю за предыдущий месяц (Столбец 'avg_class_frequency_current_month') - 1-2 дня;
#  - Столбец 'churn' показывает, что отток в текущем месяце составил 26%, стандартное отклонение - 0.44.

# %% [markdown]
# ### Посмотрите на средние значения признаков в двух группах — тех, кто ушел в отток и тех, кто остался (воспользуйтесь методом groupby())

# %%
df.groupby('churn')['gender'].agg('count') # посчитаем количество оставшихся и ушедших клиентов
# Out:
# churn
# 0    2939
# 1    1061
# Name: gender, dtype: int64

# %% [markdown]
#  2939 осталось, 1061 ушло.

# %%
df.groupby('churn').agg('mean')
# Out:
#          gender  near_location   partner  promo_friends     phone  \
# churn
# 0      0.510037       0.873086  0.534195       0.353522  0.903709
# 1      0.510839       0.768143  0.355325       0.183789  0.902922
#
#        contract_period  group_visits        age  avg_additional_charges_total  \
# churn
# 0             5.747193      0.464103  29.976523                    158.445715
# 1             1.728558      0.268615  26.989632                    115.082899
#
#        month_to_end_contract  lifetime  avg_class_frequency_total  \
# churn
# 0                   5.283089  4.711807                   2.024876
# 1                   1.662582  0.990575                   1.474995
#
#        avg_class_frequency_current_month
# churn
# 0                               2.027882
# 1                               1.044546

# %% [markdown]
#  Из сравнения средних значений видно, что:
#  - больший отток клиентов возник для тех, кто имел большую удаленность от фитнес-центра;
#  -  среди партнеров фитнес-центра оттток меньше;
#  - отток среди клиентов, использовавших промокод меньше;
#  -  поле 'phone', 'gender', 'age' не влияет на показатель оттока;
#  - поле 'contract_period', 'group_visits', 'month_to_end_contract', 'lifetime' в значительной степени влияют на показатель оттока в положительную сторону;
#  - поле 'avg_class_frequency_total' и 'avg_class_frequency_current_month' оказывают слабое положительное влияние на показатель оттока.

# %% [markdown]
# ### Постройте столбчатые гистограммы и распределения признаков для тех, кто ушёл (отток) и тех, кто остался (не попали в отток)

# %%
columns = df.columns.tolist()

def create_hist(columns):
    for i in columns:
        #Построим гистограмму. Зададим размер
        plt.figure(figsize =(10, 4))
        #Строим график
        
        sns.distplot(df.query('churn == 1')[i], bins=6,  kde=False, color='r',label='ушли')
        sns.distplot(df.query('churn == 0')[i], bins=6,  kde=False, color='y',label='остались')
        #Зададим заголовок
        plt.title('Распределение признака {}'.format(i))
        #Подишем ось x
        plt.xlabel('Значение')
        #Подпишем ось y
        plt.ylabel('Количество записей')
        plt.grid()
        plt.legend() 
        plt.show()

# %%
create_hist(columns)

# %% [markdown]
# В целом, графики совпадают с выводами выше.

# %% [markdown]
# ### Постройте матрицу корреляций и отобразите её

# %%
df_corr = df.corr()
plt.figure(figsize=(14,8))
sns.heatmap(df_corr, annot = True, square=False)
plt.title('Матрица корреляций', fontsize = 20)
plt.xlabel('Признаки', fontsize = 14)
plt.ylabel('Признаки', fontsize = 14)
plt.show()

# %% [markdown]
# Сильная корелляция наблюдается между признаками "длительность текущего действующего абонемента" и "срок до окончания текущего действующего абонемента" - 0,97. Также сильная корреляция наблюдается между признаками "средняя частота посещений в неделю за все время с начала действия абонемента" и "средняя частота посещений в неделю за предыдущий месяц" - 0,95. Более слабая корреляция между призаками "Partner"  и "Promo_friends"  - 0,45.

# %%
df= df.drop(columns=['contract_period', 'avg_class_frequency_current_month'])

# %% [markdown]
# ##  Постройте модель прогнозирования оттока клиентов

# %% [markdown]
# ### Разбейте данные на обучающую и валидационную выборку функцией train_test_split()

# %%
# (матрица X), целевая переменная (y) - факт оттока клиента в следующем месяце
X = df.drop(columns=['churn'], axis=1)
y = df['churn']

# разделяем модель на обучающую и валидационную выборку
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# ### Обучите модель на train-выборке двумя способами: логистической регрессией и случайным лесом. Оцените метрики accuracy, precision и recall для обеих моделей на валидационной выборке. Сравните по ним модели. Какая модель показала себя лучше на основании метрик?

# %%
def metrics(label, model):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    print("Модель прогнозирования -", label)
    accuracy = accuracy_score(y_test, y_pred).round(2)
    print("Доля правильных ответов: Accuracy =",accuracy)
    precision = precision_score(y_test, y_pred).round(2)
    print("Точность: precision =", precision)
    recall = recall_score(y_test, y_pred).round(2)
    print("Полнота: recall =", recall)
    f1 = f1_score(y_test, y_pred).round(2)
    print("f1 =", f1)
    roc_auc = roc_auc_score(y_test, y_pred).round(2)
    print("roc_auc", roc_auc)

# %% [markdown]
# Обучим выборку логистической регрессией:

# %%
model = LogisticRegression(random_state=0)
metrics('"Логистическая регрессия"', model)
# Out:
# Модель прогнозирования - "Логистическая регрессия"
# Доля правильных ответов: Accuracy = 0.88
# Точность: precision = 0.75
# Полнота: recall = 0.74
# f1 = 0.75
# roc_auc 0.83

# %% [markdown]
# Проделаем то же самое для случайного леса:

# %%
model = RandomForestClassifier(n_estimators = 100, random_state=0)
metrics('"Случайный лес"', model)
# Out:
# Модель прогнозирования - "Случайный лес"
# Доля правильных ответов: Accuracy = 0.9
# Точность: precision = 0.8
# Полнота: recall = 0.77
# f1 = 0.79
# roc_auc 0.85

# %% [markdown]
# Обе модели показывают достаточно высокие показатели, однако все параметры немного выше у модели "Случайный лес."

# %% [markdown]
# ## Сделайте кластеризацию клиентов

# %% [markdown]
# ### Стандартизируйте данные

# %%
sc = StandardScaler()
X_sc = sc.fit_transform(X)

# %% [markdown]
# ### Постройте матрицу расстояний функцией linkage() на стандартизованной матрице признаков и нарисуйте дендрограмму.  На основании полученного графика предположите, какое количество кластеров можно выделить.

# %%
linked = linkage(X_sc, method = 'ward') 
plt.figure(figsize=(15, 10))  
dendrogram(linked, orientation='top')
plt.show()

# %% [markdown]
# Из дентограммы видны 4 кластера, однако 4-ый кластер достаточно велик, его можно разбить на 2 или даже на 3 кластера.

# %% [markdown]
# ### Обучите модель кластеризации на основании алгоритма K-Means и спрогнозируйте кластеры клиентов. Договоримся за число кластеров принять n=5

# %%
km = KMeans(n_clusters = 5, random_state=0) 
labels = km.fit_predict(X_sc)

# %% [markdown]
# Добавим столбец с кластерами в исходную таблицу и посмотрим на количество клиентов в каждом кластере

# %%
df['cluster_km'] = labels
df.groupby('cluster_km')['gender'].agg('count')
# Out:
# cluster_km
# 0    1001
# 1     557
# 2     898
# 3    1158
# 4     386
# Name: gender, dtype: int64

# %% [markdown]
# ### Посмотрите на средние значения признаков для кластеров. Можно ли сразу что-то заметить?

# %%
df.groupby('cluster_km').agg('mean')
# Out:
#               gender  near_location   partner  promo_friends  phone  \
# cluster_km
# 0           0.498501       0.995005  0.889111       1.000000    1.0
# 1           0.500898       0.000000  0.488330       0.077199    1.0
# 2           0.521158       0.995546  0.417595       0.011136    1.0
# 3           0.512090       1.000000  0.196891       0.053541    1.0
# 4           0.523316       0.862694  0.471503       0.305699    0.0
#
#             group_visits        age  avg_additional_charges_total  \
# cluster_km
# 0               0.519481  29.543457                    152.139417
# 1               0.231598  28.685817                    137.277472
# 2               0.546771  30.805122                    177.103564
# 3               0.297064  27.818653                    124.625600
# 4               0.427461  29.297927                    144.208179
#
#             month_to_end_contract  lifetime  avg_class_frequency_total  \
# cluster_km
# ...

# %% [markdown]
# Исходя из таблицы можно заметить, что:
#  - Кластер 0 - клиенты, проживающие недалеко от клуба, сотрудники компании-партнёра клуба, пришли по акции друзей. Продолжительночть посещения 4 месяца,  на дополнительные услуги тратят довольно много, средняя частота посещений в неделю за все время с начала действия абонемента  -  2 раза в неделю, оттока низкий;
#  -  Кластер 1 - клиенты, также проживающие далеко от клуба,почти никто не использовал промокод от друзей, групповые посещения низкие, продолжительность посещения в среднем - 3 месяца, частота почти два раза в неделю, отток небольшой;
#  - Кластер 2  - клиенты, проживающие недалеко от клуба, почти никто не использовал промокод от друзей, на дополнительные услуги тратят больше всех, средняя родолжительность посещения почти 6 месяцев,средняя частота посещений в неделю за все время с начала действия абонемента  -  2,3 раза в неделю, оттока практически нет;
#  - Кластер 3 -  клиенты, проживающие в непосредственной близости к клубу,на дополнительные услуги тратят меньше всех, абонемент на 2 месяца, средняя частота посещений в неделю за все время с начала действия абонемента  -  1,5 раз в неделю, оотока самый высокий среди всех кластеров;
#  - Кластер 4 -  клиенты, проживающие довольно близко к клубу, не оставившие контактных данных, продолжительночть посещения  4 месяца,  средняя частота посещений в неделю за все время с начала действия абонемента  почти 2 раза в неделю, отток умеренный.

# %% [markdown]
# ### Постройте распределения признаков для кластеров. Можно ли что-то заметить по ним?

# %%
columns = df.columns.tolist()
for f in columns:
    g = sns.displot(df, x=df[f], hue='cluster_km', palette="rainbow", kind='hist' ) 
    plt.title(f'Признак - {f}')
    plt.ylabel("Кол-во клиентов")
    g.fig.set_figwidth(15)
    g.fig.set_figheight(6)

# %% [markdown]
#  - признак 'near_location' - сильно выделяется Кластер2 - проживающие далеко от клуба;
#  - признак 'partner' - сильно выделяется кластер 0;
#  - признак 'promo_friends' - сильно выделяется кластер 0(использовали промокод), 2/3 клиентов не использовали промокод от друзей;
#  - признак 'phone' - Кластер4 - не оставившие контактные данные;
#  - признак 'group_visits' - Кластер2 - не любители групповых занятий. Кластер0 - напротив клиенты любят групповые занятия;
#  - признак 'age' - кластер3 преимущественно состоит из клиетов с возрастом 30 лет и меньше,а кластер0 кому больше 30 лет.
#  - признак 'avg_additional_charges_total' - выделяется кластер3, который тратит до 250 и кластер0 - тратят свыше 200;
#   - признак 'lifetime' - выделяются  кластер3(посещали клуб 2мес и меньше) и кластер0(посещали клуб больше 2 месяцев)
#  - признак 'avg_class_frequency_total' - Кластер3 - те кто ходит в среднем 1 раз, кластер0 - те кто ходит 2-3раза.
#  - признак 'churn' - выделяются кластер 0 и кластер 4 с низким оотоком.

# %% [markdown]
# ### Для каждого полученного кластера посчитайте долю оттока (методом groupby()). Отличаются ли они по доле оттока? Какие кластеры склонны к оттоку, а какие — надёжны?

# %%
churn_share = df.query('churn==1').groupby('cluster_km')['churn'].count() / df.query('churn==1')['churn'].count()
churn_share

# %% [markdown]
# Кластеры с низкой долей оттока - Кластер0, Кластер1, Кластер4. Самый "опасный" кластер - Кластер 3.

# %% [markdown]
# ## Сформулируйте выводы и сделайте базовые рекомендации по работе с клиентами

# %% [markdown]
# Из сравнения средних значений видно, что:
# больший отток клиентов возник для тех, кто имел большую удаленность от фитнес-центра;
# среди партнеров фитнес-центра оттток меньше;
# отток среди клиентов, использовавших промокод меньше;
# поле 'phone', 'gender', 'age' не влияет на показатель оттока;
# поле 'contract_period', 'group_visits', 'month_to_end_contract', 'lifetime' в значительной степени влияют на показатель оттока в положительную сторону;
# поле 'avg_class_frequency_total' и 'avg_class_frequency_current_month' оказывают слабое положительное влияние на показатель оттока.
#     Сильная корелляция наблюдается между признаками "длительность текущего действующего абонемента" и "срок до окончания текущего действующего абонемента" - 0,97. Также сильная корреляция наблюдается между признаками "средняя частота посещений в неделю за все время с начала действия абонемента" и "средняя частота посещений в неделю за предыдущий месяц" - 0,95. Более слабая корреляция между призаками "Partner" и "Promo_friends" - 0,45.
#     Обе модели показывают достаточно высокие показатели, однако все параметры немного выше у модели "Случайный лес."
#     Кластер 0 - клиенты, проживающие недалеко от клуба, сотрудники компании-партнёра клуба, пришли по акции друзей. Продолжительночть посещения почти 5 месяцев, на дополнительные услуги тратят довольно много, средняя частота посещений в неделю за все время с начала действия абонемента - 2 раза в неделю, оотока практически нет;
#     Кластер 1 - клиенты, также проживающие недалеко от клуба, но чуть дальше чем в нулевом кластере, не оставившие контактных данных, продолжительность посещения в среднем - 4 месяца, частота почти два раза в неделю, отток небольшой;
#     Кластер 2 - клиенты, проживающие далеко от клуба, почти никто не использовал промокод от друзей, редко посещают групповые занятия, средняя родолжительность посещения - 1,6 месяца,средняя частота посещений в неделю за все время с начала действия абонемента - 1,5 раз в неделю, ооток довольно большой;
#     Кластер 3 - клиенты, проживающие в непосредственной близости к клубу. , абонемент на 2 месяца, средняя частота посещений в неделю за все время с начала действия абонемента - 1 раз в неделю, оотока самый высокий среди всех кластеров;
#     Кластер 4 - клиенты, проживающие довольно близко к клубу, продолжительночть посещения почти 5 месяцев, на дополнительные услуги тратят довольно много, средняя частота посещений в неделю за все время с начала действия абонемента почти 3 раза в неделю, оотока практически нет.
# признак 'near_location' - сильно выделяется Кластер2 - проживающие далеко от клуба;
# признак 'partner' - сильно выделяется кластер 0;
# признак 'promo_friends' - сильно выделяется кластер 0(использовали промокод), 2/3 клиентов не использовали промокод от друзей;
# признак 'phone' - Кластер1 - не оставившие контактные данные;
# признак 'contract_period' - Здесь хорошо видно, что абонементы продаются на периоды 1,6,12 месяцев. Кластер0 состоит преимущественно из 12месячных абонементов;
# признак 'group_visits' - Кластер2 - не любители групповых занятий. Кластер0 - напротив клиенты любят групповые занятия;
# признак 'age' - кластер3 преимущественно состоит из клиетов с возрастом 30 лет и меньше,а кластер0 кому больше 30 лет.
# признак 'avg_additional_charges_total' - выделяется кластер3, который тратит до 250 и кластер0 - тратят свыше 200;
# признак 'lifetime' - выделяются кластер3(посещали клуб 2мес и меньше) и кластер0(посещали клуб больше 2 месяцев)
# признак 'avg_class_frequency_total' и 'avg_class_frequency_current_month' - Кластер3 - те кто ходит в среднем 1 раз, кластер0 - те кто ходит 2-3раза.
# признак 'churn' - выделяются кластер 0 и кластер 4 с низким оотоком.
#
# Рекомендации: Необходимо уделить бОльшее внимание кластеру 2 и клстеру 3, так как у них самая высокая доля оотока среди клиентов, рекомендуется приняти меры по увеличению количества абонетов на 12 месяцев путем более выгодных цен или промоакций, а также парнерских программ. Проводить мастер-классы по груповым занятиям. Целевая аудитория: те клиенты, кто проживет или работает недалеко от фитнес-клуба.
